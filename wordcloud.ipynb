# %% [markdown]
# CREATING WORDCLOUD

# %%
import pandas as pd
import numpy as np
import string
import nltk
import matplotlib.pyplot as plt

# %%
text= open('/content/samplewords.txt', 'r').read()

# %%
len(text)
# Out:
# 4632

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# !pip install wordcloud

# %%
from nltk.corpus import stopwords

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
#Punctuation removal
text_punc_removed =''
for word in text:
  if word not in string.punctuation:
    text_punc_removed = text_punc_removed+word

# %%
text_punc_removed=text_punc_removed.lower()

# %%
word_cloud1 = WordCloud(collocations = False, background_color = 'white',
                        width = 2048, height = 1080).generate(text_punc_removed)
# saving the image
word_cloud1.to_file('wordcloud.png')

# %%
plt.imshow(word_cloud1, interpolation='bilinear')
plt.axis("off")
plt.show()
